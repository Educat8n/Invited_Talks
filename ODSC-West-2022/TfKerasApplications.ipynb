# %% [markdown]
# <a href="https://colab.research.google.com/github/Educat8n/Invited_Talks/blob/master/ODSC-West-2022/TfKerasApplications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.xception import preprocess_input, decode_predictions

import tensorflow as tf
import numpy as np
import requests
from PIL import Image
from io import BytesIO

import matplotlib.pyplot as plt
import numpy as np

model = Xception(weights='imagenet')

# %%
def load_image_from_url(img_url):
  response = requests.get(img_url, headers={'User-agent': 'Colab Sample (https://tensorflow.org)'})
  image = Image.open(BytesIO(response.content))
  image.save('lion.jpg')
  return image

# %%
image_size = 299
print(f"Images will be converted to {image_size}x{image_size}")
img_url =  "https://upload.wikimedia.org/wikipedia/commons/c/c6/Okonjima_Lioness.jpg"
img = load_image_from_url(img_url) 

plt.imshow(img)
# Out:
# Images will be converted to 299x299

# %%
img_path = 'lion.jpg'
img = image.load_img(img_path, target_size=(image_size, image_size))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predicted: [('n02129165', 'lion', 0.8072503), ('n02412080', 'ram', 0.013487245), ('n02114367', 'timber_wolf', 0.009154343)]

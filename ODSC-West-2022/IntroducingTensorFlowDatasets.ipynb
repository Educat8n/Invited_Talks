# %% [markdown]
# <a href="https://colab.research.google.com/github/Educat8n/Invited_Talks/blob/master/ODSC-West-2022/IntroducingTensorFlowDatasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow_datasets as tfds

# %%
data, info = tfds.load('horses_or_humans', split='train', as_supervised=True,  with_info=True) 
val_data = tfds.load('horses_or_humans', split='test', as_supervised=True)

# %%
data_train = data.take(1)
for sample, lable in data_train:
  print(sample.shape)
  print(lable)
# Out:
# (300, 300, 3)
# tf.Tensor(0, shape=(), dtype=int64)

# %%
fig = tfds.show_examples(data, info)
